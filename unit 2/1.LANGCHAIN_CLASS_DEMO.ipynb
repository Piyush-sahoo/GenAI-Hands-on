# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 3.4 MB/s eta 0:00:00

# %%
GOOGLE_APPLICATION_CREDENTIALS="AIzaSyBTA3fFhrI996n2TN7_1szUPN5FCDmE4R4"

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
if "GOOGLE_APPLICATION_CREDENTIALS" not in os.environ:
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = getpass.getpass("enter your api key")
# Out:
# enter your api key··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
import getpass

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

llm_focused = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)

llm_creative = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)
# Out:
# Enter your Google API Key: ··········

# %%
prompt = "Define the word 'idea' in one sentence."

print("-- FOCUSED (Temp=0) ---")
print(f"Run 1: {llm_focused.invoke(prompt).content}")
print(f"Run 2: {llm_focused.invoke(prompt).content}")
# Out:
# -- FOCUSED (Temp=0) ---
# Run 1: An idea is a thought, concept, or plan conceived in the mind.
# Run 2: An idea is a thought, concept, or plan conceived in the mind.

# %%
from dotenv import load_dotenv
load_dotenv()


import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your google api key:")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage(content = "you're my  uncle who keeps giving me money in the middle of conversations."),
    HumanMessage(content = "what is AI")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# AI, huh? Well, think of it like... computers getting smart. Not just following instructions, but actually learning, figuring things out, even making decisions. Here, take this twenty. Don't tell your mom I gave it to you. Go get yourself a little something, you've been working hard.
#
# Anyway, where was I? Oh right, AI. It's all about making machines think a bit more like us, you know? Like recognizing faces, understanding what you say, or even driving a car without a human touching the wheel. Pretty wild stuff, isn't it? It's basically trying to give computers a brain, in a simplified way.

# %%
from dotenv import load_dotenv
load_dotenv()


import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your google api key:")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template = ChatPromptTemplate.from_template("Tell me a fun fact about {topic}")
parser = StrOutputParser()

# %%
prompt_value = template.invoke({"topic" : "balloon"})

response_obj = llm.invoke(prompt_value)

final_text = parser.invoke(response_obj)

print(final_text)
# Out:
# Ever wonder why your voice sounds like a chipmunk after inhaling helium from a balloon?
#
# It's because **sound travels nearly three times faster through helium than through regular air!** This changes the way sound waves resonate in your vocal cords and mouth, making your voice sound higher pitched and squeaky.
#
# (Just remember, it's safer to enjoy helium in balloons than to inhale it directly, as it displaces oxygen!)

# %%
chain= template | llm| parser
print(chain.invoke({"topic" : "balloon"}))
# Out:
# Here's a fun fact about balloons:
#
# The art of creating **balloon animals** (also known as balloon twisting or balloon modeling) gained popularity in the **1930s**! While it seems like a timeless party trick, entertainers like Henry Maar are often credited with being among the first to professionalize this unique and intricate skill.
